# %% [markdown]
# # Future Map
#
# > Future Map
#
# - author: Benedict Thekkel
# - date: 04/20/2024
# - skip_showdoc: true
# - skip_exec: true

# %%
#| default_exp future

# %%
#| hide
from graphviz import Digraph
import graphviz  
from nbdevAuto.functions import graph

# %%
#| echo: false

black = '#000000'

g = graph('A', filename='Data/plan', engine = 'dot')

g.node('Intership',
        '''<<TABLE BORDER="0" CELLBORDER="0" CELLSPACING="10" CELLPADDING="10" STYLE = "rounded">
          <TR><TD PORT="Intership" BORDER="0" STYLE = "rounded" WIDTH="100" >Intership</TD></TR>
          <TR><TD PORT="Phisaver" STYLE = "rounded" BGCOLOR="#fcbf49" >Phisaver</TD></TR>
        </TABLE>>''',
        fillcolor=g.primary,
        penwidth = '0')

g.node('Business',
        '''<<TABLE BORDER="0" CELLBORDER="0" CELLSPACING="10" CELLPADDING="10" STYLE = "rounded">
          <TR><TD PORT="Business" BORDER="0" STYLE = "rounded" WIDTH="100" >Business</TD></TR>
          <TR><TD PORT="Drone" STYLE = "rounded" BGCOLOR="#fcbf49" >Drone</TD></TR>
          <TR><TD PORT="Laser" STYLE = "rounded" BGCOLOR="#fcbf49" >Laser</TD></TR>
        </TABLE>>''',
        fillcolor=g.primary,
        penwidth = '0')

g.node('Project',
        '''<<TABLE BORDER="0" CELLBORDER="0" CELLSPACING="10" CELLPADDING="10" STYLE = "rounded">
          <TR><TD PORT="f" BORDER="0" STYLE = "rounded" WIDTH="100" >Project</TD></TR>
          <TR><TD PORT="InfoAI" STYLE = "rounded" BGCOLOR="#fcbf49" >Information AI</TD></TR>
          <TR><TD PORT="3D" STYLE = "rounded" BGCOLOR="#fcbf49" >3D vision- modeling AI</TD></TR>
          <TR><TD PORT="stocks" STYLE = "rounded" BGCOLOR="#fcbf49" >Trading Algo</TD></TR>
        </TABLE>>''',
        fillcolor=g.primary,
        penwidth = '0')


g.edge('FASTAI:e', 'Thesis:w')
g.edge('Thesis:e', 'Project:3D:w')


g.edge('Intership:phisaver:e', 'Flutter:w')
g.edge('Intership:phisaver:e', 'Forecasting:w')
g.edge('Intership:phisaver:e', 'ML:w')

g.edge('Forecasting:e', 'Project:stocks:w')
g.edge('Flutter:e', 'Project:3D:w')
g.edge('Flutter:e', 'Thesis:w')

g.edge('ML:e', 'Project:w')


g.edge('Business:Laser:e','Project:w')
g.edge('Business:Laser:e', 'Manufacturer:w')

g.edge('Business:Drone:e','Project:w')
g.edge('Business:Drone:e', 'Business:Drone:w')
g.edge('Business:Drone:e', 'Manufacturer:w')



g.render(format='svg', cleanup=False)


g

# %%
#| hide

black = '#000000'

g = graph('A', filename='Data/plan', engine = 'dot')

g.node('Now',
        '''<<TABLE BORDER="0" CELLBORDER="0" CELLSPACING="10" CELLPADDING="10" STYLE = "rounded">
          <TR><TD PORT="Now" BORDER="0" STYLE = "rounded" WIDTH="100" >Now</TD></TR>
          <TR><TD PORT="Phisaver" STYLE = "rounded" BGCOLOR="#fcbf49" >Phisaver</TD></TR>
          <TR><TD PORT="RM" STYLE = "rounded" BGCOLOR="#fcbf49" >RM</TD></TR>
          <TR><TD PORT="ML" STYLE = "rounded" BGCOLOR="#fcbf49" >ML</TD></TR>
          <TR><TD PORT="DL" STYLE = "rounded" BGCOLOR="#fcbf49" >DL</TD></TR>
          <TR><TD PORT="Marketing" STYLE = "rounded" BGCOLOR="#fcbf49" >Marketing</TD></TR>
        </TABLE>>''',
        fillcolor=g.primary,
        penwidth = '0')

g.node('Towards',
        '''<<TABLE BORDER="0" CELLBORDER="0" CELLSPACING="10" CELLPADDING="10" STYLE = "rounded">
          <TR><TD PORT="Towards" BORDER="0" STYLE = "rounded" WIDTH="100" >Towards</TD></TR>
          <TR><TD PORT="Back_end" STYLE = "rounded" BGCOLOR="#fcbf49" >Back End</TD></TR>
          <TR><TD PORT="Front_end" STYLE = "rounded" BGCOLOR="#fcbf49" >Front End</TD></TR>
          <TR><TD PORT="Forecasting" STYLE = "rounded" BGCOLOR="#fcbf49" >Forecasting</TD></TR>
          <TR><TD PORT="App_development" STYLE = "rounded" BGCOLOR="#fcbf49" >App Development</TD></TR>
          <TR><TD PORT="Laser" STYLE = "rounded" BGCOLOR="#fcbf49" >Laser</TD></TR>
        </TABLE>>''',
        fillcolor=g.primary,
        penwidth = '0')

g.node('Future',
        '''<<TABLE BORDER="0" CELLBORDER="0" CELLSPACING="10" CELLPADDING="10" STYLE = "rounded">
          <TR><TD PORT="Future" BORDER="0" STYLE = "rounded" WIDTH="100" >Future</TD></TR>          
          <TR><TD PORT="Space" STYLE = "rounded" BGCOLOR="#fcbf49" >Space Company</TD></TR>
          <TR><TD PORT="Laser" STYLE = "rounded" BGCOLOR="#fcbf49" >Laser 3D printing</TD></TR>
          <TR><TD PORT="Diamond" STYLE = "rounded" BGCOLOR="#fcbf49" >Diamond Manufacture</TD></TR>
        </TABLE>>''',
        fillcolor=g.primary,
        penwidth = '0')

g.node('Project',
        '''<<TABLE BORDER="0" CELLBORDER="0" CELLSPACING="10" CELLPADDING="10" STYLE = "rounded">
          <TR><TD PORT="f" BORDER="0" STYLE = "rounded" WIDTH="100" >Project</TD></TR>
          <TR><TD PORT="InfoAI" STYLE = "rounded" BGCOLOR="#fcbf49" >Information AI</TD></TR>
          <TR><TD PORT="3D" STYLE = "rounded" BGCOLOR="#fcbf49" >3D vision- modeling AI</TD></TR>
          <TR><TD PORT="stocks" STYLE = "rounded" BGCOLOR="#fcbf49" >Trading Algo</TD></TR>
          <TR><TD PORT="Drone" STYLE = "rounded" BGCOLOR="#fcbf49" >Drone E-Commerce</TD></TR>
        </TABLE>>''',
        fillcolor=g.primary,
        penwidth = '0')



g.edge('Now:phisaver:e', 'Towards:App_development:w')
g.edge('Now:phisaver:e', 'Towards:Forecasting:w')
g.edge('Now:phisaver:e', 'Towards:Back_end:w')

g.edge('Now:RM:e', 'Towards:Front_end:w')
g.edge('Now:ML:e', 'Towards:Forecasting:w')
g.edge('Now:DL:e', 'Towards:Forecasting:w')

g.edge('Now:Marketing:e', 'Towards:Laser:w')
g.edge('Now:Marketing:e', 'Project:s')
g.edge('Now:Marketing:e', 'Future:s')

g.edge('Towards:Front_end:e', 'Project:InfoAI:w')
g.edge('Towards:Front_end:e', 'Project:3D:w')
g.edge('Towards:Front_end:e', 'Project:stocks:w')

g.edge('Towards:Back_end:e', 'Project:InfoAI:w')
g.edge('Towards:Back_end:e', 'Project:3D:w')
g.edge('Towards:Back_end:e', 'Project:stocks:w')
g.edge('Towards:Forecasting:e', 'Project:stocks:w')
g.edge('Towards:App_development:e', 'Project:InfoAI:w')
g.edge('Towards:App_development:e', 'Project:3D:w')

g.edge('Towards:Laser:e', 'Future:Laser:w')



g.edge('Project:3D:e', 'Future:Laser:w')
g.edge('Project:Drone:e', 'Future:Space:w')



g
