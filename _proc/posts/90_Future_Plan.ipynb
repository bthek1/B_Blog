# %% [raw]
# ---
# author: Benedict Thekkel
# date: 04/21/2024
# description: Breakdown of future learning goals
# output-file: future_plan.html
# skip_exec: true
# skip_showdoc: true
# title: Future Plan
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Income

# %% [markdown]
# 1. Laser
# 2. Phisaver
# 3. Recovery Metrics
# 4. Drone ecommerce
# 5. Uni Jupyter labs

# %% [markdown]
# ## Goals

# %% [markdown]
# 1. ML research - ForResNet
# 2. 3D App
# 3. Backend- RM
# 4. Frontend - Phisaver, RM
# 5. Appdevelopment - Phisaver
# 6. Marketing - Phisaver

# %% [markdown]
# ## Ideas

# %% [markdown]
# 1. spinning light
# 2. ForResnet
# 3. random forward and backward

# %% [markdown]
# ## Breakdown

# %% [markdown]
# ### Laser

# %% [markdown]
# - shipstation
# - photoshop
# - designs

# %% [markdown]
# ### FASTAI, CSSEML, MATLAB

# %% [markdown]
# ### Drone - Drop shipping

# %% [markdown]
# ### Webdevelopment

# %% [markdown]
# - oracle
# - django
# - react

# %% [markdown]
# ### App development

# %% [markdown]
# - flutter
# - 3D vision
